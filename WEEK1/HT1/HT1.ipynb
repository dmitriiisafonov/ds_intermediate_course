# %% [markdown]
# # HT 2 : Feature engineering
# ---
# В файлах приложен датасет - лог рекламных событий за один временной период ('dataset_ht1.csv'). Для этого датасета необходимо выполнить задания по **feature engineering**. Проверка задания будет осуществляться на датасете из этого же лога, но за другой временной период.

# %% [markdown]
# ### 🔧 Подготовка среды

# %%
# ! pip3 install pandas matplotlib

# %% [markdown]
# ### 1️⃣ Импорт библиотек и загрузка датасета

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dataset_ht1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                      ip_hash  \
# 0           1  76XjK3hFY0zNxVSsKbpU-z5jtDxDI3Y29zro49jeOaQ
# 1           2  _d5C-zr63nB_-VCdpXOHpu-e3w-5K_13_VHKFnIatn8
# 2           3  C1tBS_xBajjwXPoiL4DccK_rtpm_1aRaUUgXzbV7yms
# 3           4  DaoGmxexeEYFOHd42YnSrNDKKFKKl5-QIwIF1f6OC1U
# 4           5  MJWsF44nWYxvqdmFm07CZLhlANONv9_RrSP49OthSiU
#
#                                    uniqid_hash  \
# 0  Y15Ge7TaSNgLVK9tz3RxkSz-KIGYn4gm1t4r3j5XEaA
# 1  rcYeyMMqpsXH9ZD7PGeV719Fp_xzMEHjYGgcD4islxw
# 2  wvKCbLPfXepDFfXd8JGF-N7HfAjh-rn5R1iU80tpvVs
# 3  6Y5drN-gVYbEF1hR6NV26LTElydE62WEkktPfJo1lLc
# 4  _UBJKrzmzQSIxo8dgo1-ITbdjNx76BqKpUKwTRN7oHU
#
#                                     logid_hash  \
# 0  sMptv93jNdf7uuyYfkJRxIYz2omrHhcKoMtSdEP0Vt4
# 1  UkUs5D4YbgHE65lI1A_XGwP1Z24PdtspdalVewL5rXs
# 2  ldoe_40OMRydl2YVkRS3TfyU5wLdna2pAlZ0O-xVhKc
# 3  pPUL4kTwga_RGSHMx0kd8nApfBleLh5Fegj_Pamdilc
# 4  0IXIJgD-hXWeQ0a278lxno1SCY51vhi2bKL1gO_F9iU
#
#                                   orderid_hash  countertype blocktype  \
# 0  MHgmUR5y_qSB5RK70nhLKv9w_2NX2DrqcIchw3Mrr3Q            1    banner
# 1  A2IDLxIg7gZxem__iysv2-X6HfT5bPVuR9nNxmtPgTk            1    banner
# 2  O-enqeJ-s2f5f5axusE97lN-j3VwA_Rzo8674o88wVA            1      none
# 3  q_P3L1QkvYBithRT-YNas5nKm90Ev1NWQZmN2oTeXo4            1    banner
# 4  V9Vl-R-8759VlNA_VA8_0LkZ6kNq_UGJ1EUBWw_a0gc            1   preroll
#
#      browsername  eventcost detaileddevicetype  \
# 0  YandexBrowser          0            Windows
# 1  YandexBrowser          0            Android
# 2   YandexSearch          0                iOS
# 3         Chrome          0            Windows
# 4  YandexBrowser          0            Android
#
#                                              referer pagetype  \
# 0                 https://yandex.ru/games/app/334366  context
# 1                 https://dzen.ru/a/XHKGN0Zi9wDMxXsB  context
# 2  https://yandex.ru/yandsearch?yu=69798990117486...     main
# 3  https://uzmovi.tv/ujas/7484-tongacha-tirik-qol...  context
# 4  https://runtime.video.cloud.yandex.net/player/...    video
#
#                                     tagid_hash   eventtime  target  \
# 0  lLHXxdxU3gTJWtnluPzTjCrfUliCQabPGv_67f8_fe8  1748725200   False
# 1  jLEI3rlgrXd6NlaRHArrMegkdislwxd9FGPKcfdf6Ro  1748725201   False
# 2  X7Hch174-rVTH6X0UPcaDizJ3Gr_hYzhz8qdHosH3Lg  1748725202   False
# 3  NsZYfFmQVMuumfC5LMpA1S3mQlA2tUsaSqd8O_axwgI  1748725202   False
# 4  S_Tlmds_1j0y4W666tXosgqsIY8DZcKCfkvO3wcJmb8  1748725202   False
#
#                                            useragent  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  Mozilla/5.0 (Linux; arm_64; Android 14; RMX393...
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 18_2 like M...
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 4  Mozilla/5.0 (Linux; arm_64; Android 7.0; BTV-D...
#
#                                    pageid_hash
# 0  CDFXqwDRdTZkXxePSHwWPHlTZ0c54YYu1Z-HXDsiqXo
# 1  tBJ25sKPdALeIM_gy1U0FyUNOAWc6aR3x29rtuueYcM
# 2  c_0aLma-EdHvKMjffZ6FJPhMExOhnPClTAFwts4qLX0
# 3  47H3BoAn2eRpVEzx4_ku50OQRLvjRI9BsRua8Xq9hdE
# 4  uYEUdctdbPyuu3uIiBlyAGMOZ3VupWWOVW5BnWZvIuw

# %% [markdown]
# #### Описание датасета

# %% [markdown]
# `ip_hash` - ip адрес\
# `uniqid_hash` - id пользователя\
# `logid_hash` - id события\
# `orderid_hash` - id рекламной кампании\
# `countertype` - тип события (1 - показ, 2 - клик)\
# `blocktype` - тип рекламного блока\
# `browsername` - браузер\
# `eventcost` - стоимость рекламного события \
# `detaileddevicetype` - устройство пользователя\
# `referer` - реферер-ссылка, с которой пользователь перешел\
# `pagetype` - тип сайта\
# `tagid_hash` - id партнера\
# `eventtime` - время события\
# `target` - целевая переменная \
# `useragent` - юзерагент\
# `pageid_hash` - id сайта

# %% [markdown]
# ### 2️⃣ Задание 0
#
# Реализовать признаки:
#
# - количество кликов пользователя (`uniqid`) за последний час
# - количество событий с ip адреса за последние сутки
# - доля top-1 ip адреса на сайте (`pageid`) за последние сутки

# %%
# your code

# %% [markdown]
# ### 3️⃣ Задание 1
#
# Сделать 5 осмысленных признаков, которые лучше всего объясняют таргет в совокупности.
#
# Ограничения: Суммарный размер RAM для признаков не более 10 MB

# %%
# your code

# %% [markdown]
# ### 4️⃣ Задание 2 Проверить временное смещение (temporal shift) в полученных признаках.

# %%
# your code
